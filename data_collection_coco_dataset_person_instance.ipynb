# %%
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Out:
# --2021-07-13 10:17:03--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.168.203
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.168.203|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# Saving to: ‘annotations_trainval2017.zip’
#
# annotations_trainva 100%[===================>] 241.19M  45.0MB/s    in 5.8s
#
# 2021-07-13 10:17:09 (41.8 MB/s) - ‘annotations_trainval2017.zip’ saved [252907541/252907541]

# %%
# Unzip annotation file
# !unzip /content/annotations_trainval2017.zip
# Out:
# Archive:  /content/annotations_trainval2017.zip
#   inflating: annotations/instances_train2017.json
#   inflating: annotations/instances_val2017.json
#   inflating: annotations/captions_train2017.json
#   inflating: annotations/captions_val2017.json
#   inflating: annotations/person_keypoints_train2017.json
#   inflating: annotations/person_keypoints_val2017.json

# %%
from pycocotools.coco import COCO
import requests

# instantiate COCO specifying the annotations json path
coco = COCO('/content/annotations/instances_val2017.json')
# Specify a list of category names of interest
catIds = coco.getCatIds(catNms=['person'])
# Get the corresponding image ids and images using loadImgs
imgIds = coco.getImgIds(catIds=catIds)
images = coco.loadImgs(imgIds)

annIds = coco.getAnnIds(catIds = catIds,iscrowd=0)
annot = coco.loadAnns(annIds)
# Out:
# loading annotations into memory...
# Done (t=0.65s)
# creating index...
# index created!

# %%
# !mkdir /content/images/
ann_file = {}
ann_file['images'] = []
ann_file['annotations'] = []
i = 0
count = 500
for im in images[:500]:
    img_data = requests.get(im['coco_url']).content
    with open('images/' + im['file_name'], 'wb') as handler:
        handler.write(img_data)
    ann_file['images'].append(im)
    for an in annot:
      if an['image_id'] == im['id']:
        ann_file['annotations'].append(an)
        print('{} handled..'.format(i))
        i +=1
        if i == 500:
          break
    if i==500 :
      break
# Out:
# 0 handled..
# 1 handled..
# 2 handled..
# 3 handled..
# 4 handled..
# 5 handled..
# 6 handled..
# 7 handled..
# 8 handled..
# 9 handled..
# 10 handled..
# 11 handled..
# 12 handled..
# 13 handled..
# 14 handled..
# 15 handled..
# 16 handled..
# 17 handled..
# 18 handled..
# 19 handled..
# 20 handled..
# 21 handled..
# 22 handled..
# 23 handled..
# 24 handled..
# 25 handled..
# 26 handled..
# 27 handled..
# 28 handled..
# 29 handled..
# 30 handled..
# 31 handled..
# 32 handled..
# 33 handled..
# 34 handled..
# 35 handled..
# 36 handled..
# 37 handled..
# 38 handled..
# 39 handled..
# 40 handled..
# 41 handled..
# 42 handled..
# 43 handled..
# 44 handled..
# 45 handled..
# 46 handled..
# 47 handled..
# 48 handled..
# 49 handled..
# 50 handled..
# 51 handled..
# 52 handled..
# 53 handled..
# 54 handled..
# 55 handled..
# 56 handled..
# 57 handled..
# 58 handled..
# 59 handled..
# 60 handled..
# 61 handled..
# 62 handled..
# 63 handled..
# 64 handled..
# 65 handled..
# 66 handled..
# 67 handled..
# 68 handled..
# 69 handled..
# 70 handled..
# 71 handled..
# 72 handled..
# 73 handled..
# 74 handled..
# 75 handled..
# 76 handled..
# 77 handled..
# 78 handled..
# 79 handled..
# 80 handled..
# 81 handled..
# 82 handled..
# 83 handled..
# 84 handled..
# 85 handled..
# 86 handled..
# 87 handled..
# 88 handled..
# 89 handled..
# 90 handled..
# 91 handled..
# 92 handled..
# 93 handled..
# 94 handled..
# 95 handled..
# 96 handled..
# 97 handled..
# 98 handled..
# 99 handled..
# 100 handled..
# 101 handled..
# 102 handled..
# 103 handled..
# 104 handled..
# 105 handled..
# 106 handled..
# 107 handled..
# 108 handled..
# 109 handled..
# 110 handled..
# 111 handled..
# 112 handled..
# 113 handled..
# 114 handled..
# 115 handled..
# 116 handled..
# 117 handled..
# 118 handled..
# 119 handled..
# 120 handled..
# 121 handled..
# 122 handled..
# 123 handled..
# 124 handled..
# 125 handled..
# 126 handled..
# 127 handled..
# 128 handled..
# 129 handled..
# 130 handled..
# 131 handled..
# 132 handled..
# 133 handled..
# 134 handled..
# 135 handled..
# 136 handled..
# 137 handled..
# 138 handled..
# 139 handled..
# 140 handled..
# 141 handled..
# 142 handled..
# 143 handled..
# 144 handled..
# 145 handled..
# 146 handled..
# 147 handled..
# 148 handled..
# 149 handled..
# 150 handled..
# 151 handled..
# 152 handled..
# 153 handled..
# 154 handled..
# 155 handled..
# 156 handled..
# 157 handled..
# 158 handled..
# 159 handled..
# 160 handled..
# 161 handled..
# 162 handled..
# 163 handled..
# 164 handled..
# 165 handled..
# 166 handled..
# 167 handled..
# 168 handled..
# 169 handled..
# 170 handled..
# 171 handled..
# 172 handled..
# 173 handled..
# 174 handled..
# 175 handled..
# 176 handled..
# 177 handled..
# 178 handled..
# 179 handled..
# 180 handled..
# 181 handled..
# 182 handled..
# 183 handled..
# 184 handled..
# 185 handled..
# 186 handled..
# 187 handled..
# 188 handled..
# 189 handled..
# 190 handled..
# 191 handled..
# 192 handled..
# 193 handled..
# 194 handled..
# 195 handled..
# 196 handled..
# 197 handled..
# 198 handled..
# 199 handled..
# 200 handled..
# 201 handled..
# 202 handled..
# 203 handled..
# 204 handled..
# 205 handled..
# 206 handled..
# 207 handled..
# 208 handled..
# 209 handled..
# 210 handled..
# 211 handled..
# 212 handled..
# 213 handled..
# 214 handled..
# 215 handled..
# 216 handled..
# 217 handled..
# 218 handled..
# 219 handled..
# 220 handled..
# 221 handled..
# 222 handled..
# 223 handled..
# 224 handled..
# 225 handled..
# 226 handled..
# 227 handled..
# 228 handled..
# 229 handled..
# 230 handled..
# 231 handled..
# 232 handled..
# 233 handled..
# 234 handled..
# 235 handled..
# 236 handled..
# 237 handled..
# 238 handled..
# 239 handled..
# 240 handled..
# 241 handled..
# 242 handled..
# 243 handled..
# 244 handled..
# 245 handled..
# 246 handled..
# 247 handled..
# 248 handled..
# 249 handled..
# 250 handled..
# 251 handled..
# 252 handled..
# 253 handled..
# 254 handled..
# 255 handled..
# 256 handled..
# 257 handled..
# 258 handled..
# 259 handled..
# 260 handled..
# 261 handled..
# 262 handled..
# 263 handled..
# 264 handled..
# 265 handled..
# 266 handled..
# 267 handled..
# 268 handled..
# 269 handled..
# 270 handled..
# 271 handled..
# 272 handled..
# 273 handled..
# 274 handled..
# 275 handled..
# 276 handled..
# 277 handled..
# 278 handled..
# 279 handled..
# 280 handled..
# 281 handled..
# 282 handled..
# 283 handled..
# 284 handled..
# 285 handled..
# 286 handled..
# 287 handled..
# 288 handled..
# 289 handled..
# 290 handled..
# 291 handled..
# 292 handled..
# 293 handled..
# 294 handled..
# 295 handled..
# 296 handled..
# 297 handled..
# 298 handled..
# 299 handled..
# 300 handled..
# 301 handled..
# 302 handled..
# 303 handled..
# 304 handled..
# 305 handled..
# 306 handled..
# 307 handled..
# 308 handled..
# 309 handled..
# 310 handled..
# 311 handled..
# 312 handled..
# 313 handled..
# 314 handled..
# 315 handled..
# 316 handled..
# 317 handled..
# 318 handled..
# 319 handled..
# 320 handled..
# 321 handled..
# 322 handled..
# 323 handled..
# 324 handled..
# 325 handled..
# 326 handled..
# 327 handled..
# 328 handled..
# 329 handled..
# 330 handled..
# 331 handled..
# 332 handled..
# 333 handled..
# 334 handled..
# 335 handled..
# 336 handled..
# 337 handled..
# 338 handled..
# 339 handled..
# 340 handled..
# 341 handled..
# 342 handled..
# 343 handled..
# 344 handled..
# 345 handled..
# 346 handled..
# 347 handled..
# 348 handled..
# 349 handled..
# 350 handled..
# 351 handled..
# 352 handled..
# 353 handled..
# 354 handled..
# 355 handled..
# 356 handled..
# 357 handled..
# 358 handled..
# 359 handled..
# 360 handled..
# 361 handled..
# 362 handled..
# 363 handled..
# 364 handled..
# 365 handled..
# 366 handled..
# 367 handled..
# 368 handled..
# 369 handled..
# 370 handled..
# 371 handled..
# 372 handled..
# 373 handled..
# 374 handled..
# 375 handled..
# 376 handled..
# 377 handled..
# 378 handled..
# 379 handled..
# 380 handled..
# 381 handled..
# 382 handled..
# 383 handled..
# 384 handled..
# 385 handled..
# 386 handled..
# 387 handled..
# 388 handled..
# 389 handled..
# 390 handled..
# 391 handled..
# 392 handled..
# 393 handled..
# 394 handled..
# 395 handled..
# 396 handled..
# 397 handled..
# 398 handled..
# 399 handled..
# 400 handled..
# 401 handled..
# 402 handled..
# 403 handled..
# 404 handled..
# 405 handled..
# 406 handled..
# 407 handled..
# 408 handled..
# 409 handled..
# 410 handled..
# 411 handled..
# 412 handled..
# 413 handled..
# 414 handled..
# 415 handled..
# 416 handled..
# 417 handled..
# 418 handled..
# 419 handled..
# 420 handled..
# 421 handled..
# 422 handled..
# 423 handled..
# 424 handled..
# 425 handled..
# 426 handled..
# 427 handled..
# 428 handled..
# 429 handled..
# 430 handled..
# 431 handled..
# 432 handled..
# 433 handled..
# 434 handled..
# 435 handled..
# 436 handled..
# 437 handled..
# 438 handled..
# 439 handled..
# 440 handled..
# 441 handled..
# 442 handled..
# 443 handled..
# 444 handled..
# 445 handled..
# 446 handled..
# 447 handled..
# 448 handled..
# 449 handled..
# 450 handled..
# 451 handled..
# 452 handled..
# 453 handled..
# 454 handled..
# 455 handled..
# 456 handled..
# 457 handled..
# 458 handled..
# 459 handled..
# 460 handled..
# 461 handled..
# 462 handled..
# 463 handled..
# 464 handled..
# 465 handled..
# 466 handled..
# 467 handled..
# 468 handled..
# 469 handled..
# 470 handled..
# 471 handled..
# 472 handled..
# 473 handled..
# 474 handled..
# 475 handled..
# 476 handled..
# 477 handled..
# 478 handled..
# 479 handled..
# 480 handled..
# 481 handled..
# 482 handled..
# 483 handled..
# 484 handled..
# 485 handled..
# 486 handled..
# 487 handled..
# 488 handled..
# 489 handled..
# 490 handled..
# 491 handled..
# 492 handled..
# 493 handled..
# 494 handled..
# 495 handled..
# 496 handled..
# 497 handled..
# 498 handled..
# 499 handled..

# %%
# Create json file
import json 

with open('person.json','w') as f:
  json.dump(ann_file,f)

# %%
# !mkdir /content/drive/MyDrive/person_COCO/
# !cp -r /content/images/ /content/drive/MyDrive/person_COCO/Images/
# !cp /content/person.json /content/drive/MyDrive/person_COCO/

# %%
import os
list = os.listdir('/content/images')
number_files = len(list)
print(number_files)
# Out:
# 139
