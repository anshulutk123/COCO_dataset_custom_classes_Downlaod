# %%
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Out:
# --2021-07-12 18:09:38--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.164.57
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.164.57|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# Saving to: ‘annotations_trainval2017.zip’
#
# annotations_trainva 100%[===================>] 241.19M  16.2MB/s    in 17s
#
# 2021-07-12 18:09:56 (14.4 MB/s) - ‘annotations_trainval2017.zip’ saved [252907541/252907541]

# %%
# Unzip annotation file
# !unzip /content/annotations_trainval2017.zip
# Out:
# Archive:  /content/annotations_trainval2017.zip
#   inflating: annotations/instances_train2017.json
#   inflating: annotations/instances_val2017.json
#   inflating: annotations/captions_train2017.json
#   inflating: annotations/captions_val2017.json
#   inflating: annotations/person_keypoints_train2017.json
#   inflating: annotations/person_keypoints_val2017.json

# %%
from pycocotools.coco import COCO
import requests

# instantiate COCO specifying the annotations json path
coco = COCO('/content/annotations/instances_val2017.json')
# Specify a list of category names of interest
catIds = coco.getCatIds(catNms=['boat'])
# Get the corresponding image ids and images using loadImgs
imgIds = coco.getImgIds(catIds=catIds)
images = coco.loadImgs(imgIds)

annIds = coco.getAnnIds(catIds = catIds,iscrowd=0)
annot = coco.loadAnns(annIds)
# Out:
# loading annotations into memory...
# Done (t=0.67s)
# creating index...
# index created!

# %%
# !mkdir /content/images/
ann_file = {}
ann_file['images'] = []
ann_file['annotations'] = []
i = 1
count = 500
for im in images[:count]:
    img_data = requests.get(im['coco_url']).content
    with open('/content/images/' + im['file_name'], 'wb') as handler:
        handler.write(img_data)
    ann_file['images'].append(im)
    for an in annot:
      if an['image_id'] == im['id']:
        ann_file['annotations'].append(an)
        print('{} downloaded..'.format(i))
        i +=1
# Out:
# 1 downloaded..
# 2 downloaded..
# 3 downloaded..
# 4 downloaded..
# 5 downloaded..
# 6 downloaded..
# 7 downloaded..
# 8 downloaded..
# 9 downloaded..
# 10 downloaded..
# 11 downloaded..
# 12 downloaded..
# 13 downloaded..
# 14 downloaded..
# 15 downloaded..
# 16 downloaded..
# 17 downloaded..
# 18 downloaded..
# 19 downloaded..
# 20 downloaded..
# 21 downloaded..
# 22 downloaded..
# 23 downloaded..
# 24 downloaded..
# 25 downloaded..
# 26 downloaded..
# 27 downloaded..
# 28 downloaded..
# 29 downloaded..
# 30 downloaded..
# 31 downloaded..
# 32 downloaded..
# 33 downloaded..
# 34 downloaded..
# 35 downloaded..
# 36 downloaded..
# 37 downloaded..
# 38 downloaded..
# 39 downloaded..
# 40 downloaded..
# 41 downloaded..
# 42 downloaded..
# 43 downloaded..
# 44 downloaded..
# 45 downloaded..
# 46 downloaded..
# 47 downloaded..
# 48 downloaded..
# 49 downloaded..
# 50 downloaded..
# 51 downloaded..
# 52 downloaded..
# 53 downloaded..
# 342 downloaded..
# 343 downloaded..
# 344 downloaded..
# 345 downloaded..
# 346 downloaded..
# 347 downloaded..
# 348 downloaded..
# 349 downloaded..
# 350 downloaded..
# 351 downloaded..
# 352 downloaded..
# 353 downloaded..
# 354 downloaded..
# 355 downloaded..
# 356 downloaded..
# 357 downloaded..
# 358 downloaded..
# 359 downloaded..
# 360 downloaded..
# 361 downloaded..
# 362 downloaded..
# 363 downloaded..
# 364 downloaded..
# 365 downloaded..
# 366 downloaded..
# 367 downloaded..
# 368 downloaded..
# 369 downloaded..
# 370 downloaded..
# 371 downloaded..
# 372 downloaded..
# 373 downloaded..
# 374 downloaded..
# 375 downloaded..
# 376 downloaded..
# 377 downloaded..
# 378 downloaded..
# 379 downloaded..
# 380 downloaded..
# 381 downloaded..
# 382 downloaded..
# 383 downloaded..
# 384 downloaded..
# 385 downloaded..
# 386 downloaded..
# 387 downloaded..
# 388 downloaded..
# 389 downloaded..
# 390 downloaded..
# 391 downloaded..
# 392 downloaded..
# 393 downloaded..
# 394 downloaded..
# 395 downloaded..
# 396 downloaded..
# 397 downloaded..
# 398 downloaded..
# 399 downloaded..
# 400 downloaded..
# 401 downloaded..
# 402 downloaded..
# 403 downloaded..
# 404 downloaded..
# 405 downloaded..
# 406 downloaded..
# 407 downloaded..
# 408 downloaded..
# 409 downloaded..
# 410 downloaded..
# 411 downloaded..
# 412 downloaded..
# 413 downloaded..
# 414 downloaded..
# 415 downloaded..
# 416 downloaded..
# 417 downloaded..
# 418 downloaded..
# 419 downloaded..
# 420 downloaded..
# 421 downloaded..
# 422 downloaded..
# 423 downloaded..
# 424 downloaded..

# %%
# Create json file
import json 

with open('boat.json','w') as f:
  json.dump(ann_file,f)

# %%
# !mkdir /content/drive/MyDrive/boat_COCO/
# !cp -r /content/images/ /content/drive/MyDrive/boat_COCO/Images/
# !cp /content/boat.json /content/drive/MyDrive/boat_COCO/

# %%
import  requests
from collections import Counter
x= "license": 3

json_obj = "/content/drive/MyDrive/boat_COCO/boat.json"

count = 0
for ele in json_obj:
    if (ele == x):
        count = count + 1
print(count)
# Out:
# 0

# %%
j =0
for i,im in enumerate(images[:1]):
  
  for an in annot:
    if an['image_id'] == im['id']:
      print(j)
      print(an)
      j += 1
# Out:
# 0
# {'segmentation': [[457.27, 203.76, 476.27, 193.64, 494.63, 185.41, 508.55, 172.11, 525.01, 151.22, 531.34, 146.79, 540.21, 146.79, 538.31, 156.92, 531.34, 164.51, 524.38, 184.77, 518.05, 206.93, 506.65, 225.29, 495.26, 237.32, 473.73, 258.21, 466.77, 239.22, 457.27, 226.55], [439.55, 214.53, 447.78, 208.83, 449.04, 221.49, 440.07, 215.05]], 'area': 3646.7868999999996, 'iscrowd': 0, 'image_id': 491008, 'bbox': [439.55, 146.79, 100.66, 111.42], 'category_id': 9, 'id': 1374901}
